# %%
import pandas as pd
import geopandas as gpd
import fiona

# %%
url_dict = {  
2017_2020: "https://opendata.arcgis.com/datasets/4eea8bf452e34f8c9d9ac07c54c0b4ab_0.geojson"
}

# %%
def merge_years(url_dict):
    df_dict={}
    for i in url_dict.keys():
        df = gpd.read_file(url_dict.get(i)) #ping url for geojson file and read in as geopandas df
        df_dict.update({i:df}) #assign each df to a year in the dict
    return(df_dict)

# %%
dfFood=merge_years(url_dict)

# %%
def merge_gpd_dfs(df_dict):
    df_list=list(df_dict.values()) #take dataframes from dict and turn into list
    df = pd.concat(df_list, ignore_index=True, sort=True) #concatenate the dataframes
    crs = df_list[0].crs #capture coordinate system from first record
    df = gpd.GeoDataFrame(df,crs=crs) # transform dataframe into geopandas dataframe
    return(df)

# %%
df=merge_gpd_dfs(dfFood)

# %%
df.head().T
# Out:
#                                               0  \
# LIC#RB                                LIC107101
# LIC_Cat                              RESTAURANT
# Business_Name                    SOTAROL UPTOWN
# Risk Lvl                                      1
# Full_Address                  2935 GIRARD AVE S
# Addr Num                                   2935
# Addr Num Suffix                             NaN
# Street Name                              GIRARD
# Street Type                                 AVE
# Post Dir                                      S
# Unit                                        NaN
# City                                Minneapolis
# State                                        MN
# County                                 Hennepin
# Zip Code                                  55408
# Inspection Type                       Follow-Up
# Inspection Result                      Complete
# Completed Date       2018-09-11 13:04:59.999000
# Inspector Name                    Mohamed Yusuf
# Src Insp Key                             255565
# Food Code Text                              NaN
# Comments                                    NaN
# Priority                                    NaN
# Standard Group                              NaN
# Year Completed Date                        2018
# Violation Status                            NaN
# ViolationPoints                             NaN
# Inspection Score                            100
# Violation ID Number                         NaN
# APN                               3302924430211
# Ward                                         10
# Neighborhood                    Lowry Hill East
# Latitude                                44.9489
# Longitude                              -93.2966
# X WebMercator                      -1.03857e+07
# Y WebMercator                       5.61347e+06
#
#                                                                      1  \
# LIC#RB                                                       LIC107101
# LIC_Cat                                                     RESTAURANT
# Business_Name                                           SOTAROL UPTOWN
# Risk Lvl                                                             1
# Full_Address                                         2935 GIRARD AVE S
# Addr Num                                                          2935
# Addr Num Suffix                                                    NaN
# Street Name                                                     GIRARD
# Street Type                                                        AVE
# Post Dir                                                             S
# Unit                                                               NaN
# City                                                       Minneapolis
# State                                                               MN
# County                                                        Hennepin
# Zip Code                                                         55408
# Inspection Type                                                Routine
# Inspection Result                                             Complete
# Completed Date                                     2017-07-15 15:30:00
# Inspector Name                                           Mohamed Yusuf
# Src Insp Key                                                    194952
# Food Code Text       Develop written procedures prior to using  tim...
# Comments             ESTABLISHMENT IS USING TIME AS PUBLIC HEALTH C...
# Priority                                                     Priority2
# Standard Group                                      MN Rule 4626.0408A
# Year Completed Date                                               2017
# Violation Status                                              Observed
# ViolationPoints                                                      2
# Inspection Score                                                    94
# Violation ID Number                                             625814
# APN                                                      3302924430211
# Ward                                                                10
# Neighborhood                                           Lowry Hill East
# Latitude                                                       44.9489
# Longitude                                                     -93.2966
# X WebMercator                                             -1.03857e+07
# Y WebMercator                                              5.61347e+06
#
#                                                                      2  \
# LIC#RB                                                       LIC107101
# LIC_Cat                                                     RESTAURANT
# Business_Name                                           SOTAROL UPTOWN
# Risk Lvl                                                             1
# Full_Address                                         2935 GIRARD AVE S
# Addr Num                                                          2935
# Addr Num Suffix                                                    NaN
# Street Name                                                     GIRARD
# Street Type                                                        AVE
# Post Dir                                                             S
# Unit                                                               NaN
# City                                                       Minneapolis
# State                                                               MN
# County                                                        Hennepin
# Zip Code                                                         55408
# Inspection Type                                                Routine
# Inspection Result                                             Complete
# Completed Date                                     2017-07-15 15:30:00
# Inspector Name                                           Mohamed Yusuf
# Src Insp Key                                                    194952
# Food Code Text       When using time only as a public health contro...
# Comments             ESTABLISHMENT WAS SUPPOSED TO USE TIMERS TO MO...
# Priority                                                     Priority1
# Standard Group                                      MN Rule 4626.0408B
# Year Completed Date                                               2017
# Violation Status                                              Observed
# ViolationPoints                                                      4
# Inspection Score                                                    94
# Violation ID Number                                             625816
# APN                                                      3302924430211
# Ward                                                                10
# Neighborhood                                           Lowry Hill East
# Latitude                                                       44.9489
# Longitude                                                     -93.2966
# X WebMercator                                             -1.03857e+07
# Y WebMercator                                              5.61347e+06
#
#                                                                      3  \
# LIC#RB                                                       LIC107101
# LIC_Cat                                                     RESTAURANT
# Business_Name                                           SOTAROL UPTOWN
# Risk Lvl                                                             1
# Full_Address                                         2935 GIRARD AVE S
# Addr Num                                                          2935
# Addr Num Suffix                                                    NaN
# Street Name                                                     GIRARD
# Street Type                                                        AVE
# Post Dir                                                             S
# Unit                                                               NaN
# City                                                       Minneapolis
# State                                                               MN
# County                                                        Hennepin
# Zip Code                                                         55408
# Inspection Type                                                Routine
# Inspection Result                                             Complete
# Completed Date                              2018-07-18 13:49:59.999000
# Inspector Name                                           Mohamed Yusuf
# Src Insp Key                                                    204578
# Food Code Text       Develop written procedures prior to using  tim...
# Comments                                                           NaN
# Priority                                                     Priority2
# Standard Group                                      MN Rule 4626.0408A
# Year Completed Date                                               2018
# Violation Status                                              Observed
# ViolationPoints                                                      2
# Inspection Score                                                    92
# Violation ID Number                                             625815
# APN                                                      3302924430211
# Ward                                                                10
# Neighborhood                                           Lowry Hill East
# Latitude                                                       44.9489
# Longitude                                                     -93.2966
# X WebMercator                                             -1.03857e+07
# Y WebMercator                                              5.61347e+06
#
#                                                                      4
# LIC#RB                                                       LIC107101
# LIC_Cat                                                     RESTAURANT
# Business_Name                                           SOTAROL UPTOWN
# Risk Lvl                                                             1
# Full_Address                                         2935 GIRARD AVE S
# Addr Num                                                          2935
# Addr Num Suffix                                                    NaN
# Street Name                                                     GIRARD
# Street Type                                                        AVE
# Post Dir                                                             S
# Unit                                                               NaN
# City                                                       Minneapolis
# State                                                               MN
# County                                                        Hennepin
# Zip Code                                                         55408
# Inspection Type                                                Routine
# Inspection Result                                             Complete
# Completed Date                              2018-07-18 13:49:59.999000
# Inspector Name                                           Mohamed Yusuf
# Src Insp Key                                                    204578
# Food Code Text       Employ a certified food protection manager (CF...
# Comments             ESTABLISHMENT DOES NOT CURRENTLY HAVE AN MDH C...
# Priority                                                     Priority3
# Standard Group                                      MN Rule 4626.0033A
# Year Completed Date                                               2018
# Violation Status                                              Observed
# ViolationPoints                                                      0
# Inspection Score                                                    92
# Violation ID Number                                             681981
# APN                                                      3302924430211
# Ward                                                                10
# Neighborhood                                           Lowry Hill East
# Latitude                                                       44.9489
# Longitude                                                     -93.2966
# X WebMercator                                             -1.03857e+07
# Y WebMercator                                              5.61347e+06

# %%
#use for pulling data from geopandas web url 
def cleanInspections(df):
    df = df[df.InspectionType=="Routine"]
    df = df[df.FacilityCategory.isin(["RESTAURANT","GROCERY"])]
    df = df[df.YearOfInspection.isin([2017,2018,2019])]
    #df = df[df.ViolationPriority=="Priority1"]
    df = df.drop(labels=['OBJECTID',  
        'FacilityCategory','RiskLevel', 'FullAddress', 'AddrNum', 'AddrNumSuffix',
       'StreetName', 'StreetType', 'PostDir', 'Unit', 'City', 'State',
       'County', 'ZipCode','InspectionResult', 'FoodCodeText',
                         'ViolationStatus', 'ViolationPoints','FoodCodeItem',
       'InspectorComments', 'APN', 'Ward', 
                         'X_WebMercator', 'Y_WebMercator'
       ],axis=1)
    return(df)

# %%
df.columns
# Out:
# Index(['LIC#RB', 'LIC_Cat', 'Business_Name', 'Risk Lvl', 'Full_Address',
#        'Addr Num', 'Addr Num Suffix', 'Street Name', 'Street Type', 'Post Dir',
#        'Unit', 'City', 'State', 'County', 'Zip Code', 'Inspection Type',
#        'Inspection Result', 'Completed Date', 'Inspector Name', 'Src Insp Key',
#        'Food Code Text', 'Comments', 'Priority', 'Standard Group',
#        'Year Completed Date', 'Violation Status', 'ViolationPoints',
#        'Inspection Score', 'Violation ID Number', 'APN', 'Ward',
#        'Neighborhood', 'Latitude', 'Longitude', 'X WebMercator',
#        'Y WebMercator'],
#       dtype='object')

# %%
sorted(df.columns)
# Out:
# ['addr_num',
#  'addr_num_suffix',
#  'apn',
#  'business_name',
#  'city',
#  'comments',
#  'completed_date',
#  'county',
#  'food_code_text',
#  'full_address',
#  'inspection_result',
#  'inspection_score',
#  'inspection_type',
#  'inspector_name',
#  'latitude',
#  'lic#rb',
#  'lic_cat',
#  'longitude',
#  'neighborhood',
#  'post_dir',
#  'priority',
#  'risk_lvl',
#  'src_insp_key',
#  'standard_group',
#  'state',
#  'street_name',
#  'street_type',
#  'unit',
#  'violation_id_number',
#  'violation_status',
#  'violationpoints',
#  'ward',
#  'x_webmercator',
#  'y_webmercator',
#  'year_completed_date',
#  'zip_code']

# %%
df.street_name.value_counts()
# Out:
# Observed             176332
# Corrected on-site     23111
# Name: street_name, dtype: int64

# %%
df['lic#rb'].value_counts()
# Out:
# LIC44358     391
# LIC53789     336
# LIC41848     330
# LIC47646     313
# LIC49683     304
#             ...
# LIC52998       1
# LIC49980       1
# LIC30785       1
# LIC33347       1
# LIC379448      1
# Name: lic#rb, Length: 8050, dtype: int64

# %%
df=pd.read_excel('/Users/Simon/Documents/UW Data Science/DS785 Capstone/Minneapolis Open Data/Minneapolis_Inspections_Full.xlsx')

# %%
# use for cleaning data from excel
def cleanInspections(df):
    df.columns = df.columns.str.replace(' ', '_')
    df.columns = df.columns.str.lower()
    #df.columns = sorted(df.columns)
    df = df[df.inspection_type=="Routine"]
    df = df[df.lic_cat.isin(["RESTAURANT","GROCERY"])]
    #df = df[df.YearOfInspection.isin([2017,2018,2019])]
    #df = df[df.ViolationPriority=="Priority1"]
    df = df.drop(labels=[
        'addr_num',
        'addr_num_suffix',
        'apn',
        'city',
        'comments',
        'county',
        'food_code_text',
        'full_address',
        'inspection_result',
        'post_dir',
        'standard_group',
        'state',
        'street_name',
        'street_type',
        'unit',
        'violation_status',
        'violationpoints',
        'ward',
        'x_webmercator',
        'y_webmercator',
        'zip_code'
       ],axis=1)
    df=df.rename(columns={
        'lic#rb':'health_license_id',
        'lic_cat':'facility_category',
        'completed_date':'date_of_inspection',
        'src_insp_key':'inspection_id_number',
        'year_completed_date':'year_of_inspection'})
    df['priority_1_ind']=df.priority=='Priority1'
    df['priority_2_ind']=df.priority=='Priority2'
    df['priority_3_ind']=df.priority=='Priority3'
    return(df)

# %%
dfCleanFood=cleanInspections(df)

# %%
dfCleanFood.columns
# Out:
# Index(['health_license_id', 'facility_category', 'business_name', 'risk_lvl',
#        'inspection_type', 'date_of_inspection', 'inspector_name',
#        'inspection_id_number', 'priority', 'year_of_inspection',
#        'inspection_score', 'violation_id_number', 'neighborhood', 'latitude',
#        'longitude', 'priority_1_ind', 'priority_2_ind', 'priority_3_ind'],
#       dtype='object')

# %%
dfCleanFood.head()
# Out:
#   health_license_id facility_category   business_name risk_lvl  \
# 1         LIC107101        RESTAURANT  SOTAROL UPTOWN        1
# 2         LIC107101        RESTAURANT  SOTAROL UPTOWN        1
# 3         LIC107101        RESTAURANT  SOTAROL UPTOWN        1
# 4         LIC107101        RESTAURANT  SOTAROL UPTOWN        1
# 5         LIC107101        RESTAURANT  SOTAROL UPTOWN        1
#
#   inspection_type      date_of_inspection inspector_name  \
# 1         Routine 2017-07-15 15:30:00.000  Mohamed Yusuf
# 2         Routine 2017-07-15 15:30:00.000  Mohamed Yusuf
# 3         Routine 2018-07-18 13:49:59.999  Mohamed Yusuf
# 4         Routine 2018-07-18 13:49:59.999  Mohamed Yusuf
# 5         Routine 2018-07-18 13:49:59.999  Mohamed Yusuf
#
#    inspection_id_number   priority  year_of_inspection  inspection_score  \
# 1                194952  Priority2                2017                94
# 2                194952  Priority1                2017                94
# 3                204578  Priority2                2018                92
# 4                204578  Priority3                2018                92
# 5                204578  Priority2                2018                92
#
#    violation_id_number     neighborhood  latitude  longitude  priority_1_ind  \
# 1             625814.0  Lowry Hill East  44.94885  -93.29663           False
# 2             625816.0  Lowry Hill East  44.94885  -93.29663            True
# 3             625815.0  Lowry Hill East  44.94885  -93.29663           False
# 4             681981.0  Lowry Hill East  44.94885  -93.29663           False
# 5             681984.0  Lowry Hill East  44.94885  -93.29663           False
#
#    priority_2_ind  priority_3_ind
# 1            True           False
# 2           False           False
# 3            True           False
# 4           False            True
# 5            True           False

# %%
df=dfCleanFood

# %%
# df['priority_1_ind']=df.ViolationPriority=='Priority1'
# df['priority_2_ind']=df.ViolationPriority=='Priority2'
# df['priority_3_ind']=df.ViolationPriority=='Priority3'

# %% [markdown]
# Create a data frame that is grouped to the inspection level

# %%
# dfInspections=df.groupby(['BusinessName', 'DateOfInspection', 'HealthFacilityIDNumber',
#        'InspectionIDNumber', 'InspectionScore', 'InspectionType', 'Latitude',
#        'Longitude', 'Neighborhood',
#        'YearOfInspection']).aggregate({'priority_1_ind':'sum','priority_2_ind':'sum','priority_3_ind':'sum'}).reset_index()

dfInspections=df.groupby(['business_name', 'date_of_inspection', 'health_license_id',
       'inspection_id_number', 'inspection_score', 'inspection_type', 'latitude',
       'longitude', 'neighborhood', 'inspector_name','facility_category','risk_lvl',
       'year_of_inspection']).aggregate({'priority_1_ind':'sum','priority_2_ind':'sum','priority_3_ind':'sum'}).reset_index()

# %%
dfInspections
# Out:
#                         business_name      date_of_inspection  \
# 0      1010 WASHINGTON WINE & SPIRITS 2015-02-27 10:10:00.000
# 1      1010 WASHINGTON WINE & SPIRITS 2017-01-27 12:19:59.999
# 2      1010 WASHINGTON WINE & SPIRITS 2019-02-06 13:20:00.000
# 3                          112 EATERY 2008-09-09 14:09:59.999
# 4                          112 EATERY 2009-11-07 15:45:00.000
# ...                               ...                     ...
# 21537                     ZUMBRO CAFE 2016-11-03 11:29:59.999
# 21538                     ZUMBRO CAFE 2016-11-03 11:29:59.999
# 21539                     ZUMBRO CAFE 2017-10-25 11:40:00.000
# 21540                     ZUMBRO CAFE 2018-12-07 12:19:59.999
# 21541                     ZUMBRO CAFE 2020-01-07 12:00:00.000
#
#       health_license_id  inspection_id_number  inspection_score  \
# 0              LIC42954                 44311                96
# 1              LIC42954                 44314                96
# 2              LIC42954                189485                96
# 3              LIC42959                 44316                82
# 4              LIC42959                 44315                92
# ...                 ...                   ...               ...
# 21537          LIC30942                 24280                92
# 21538          LIC30944                 24301               100
# 21539          LIC30942                 24300                80
# 21540          LIC30942                236468                96
# 21541          LIC30942                281116                96
#
#       inspection_type  latitude  longitude   neighborhood    inspector_name  \
# 0             Routine  44.97659  -93.25502  Downtown East     Jim S Donovan
# 1             Routine  44.97659  -93.25502  Downtown East   Alexander S Kim
# 2             Routine  44.97659  -93.25502  Downtown East      Bob V Becker
# 3             Routine  44.98266  -93.27156  Downtown West        Ellen Hoyt
# 4             Routine  44.98266  -93.27156  Downtown West     Mohamed Yusuf
# ...               ...       ...        ...            ...               ...
# 21537         Routine  44.92447  -93.31501   Linden Hills     Graham Miller
# 21538         Routine  44.92447  -93.31501   Linden Hills     Graham Miller
# 21539         Routine  44.92447  -93.31501   Linden Hills  Eduardo Mardones
# 21540         Routine  44.92447  -93.31501   Linden Hills        SEID SHEKA
# 21541         Routine  44.92447  -93.31501   Linden Hills    Kristine Molde
#
#       facility_category risk_lvl  year_of_inspection  priority_1_ind  \
# 0               GROCERY        3                2015             1.0
# 1               GROCERY        3                2017             1.0
# 2               GROCERY        3                2019             0.0
# 3            RESTAURANT        1                2008             3.0
# 4            RESTAURANT        1                2009             1.0
# ...                 ...      ...                 ...             ...
# 21537        RESTAURANT        1                2016             2.0
# 21538        RESTAURANT        1                2016             0.0
# 21539        RESTAURANT        1                2017             3.0
# 21540        RESTAURANT        1                2018             0.0
# 21541        RESTAURANT        1                2020             1.0
#
#        priority_2_ind  priority_3_ind
# 0                 0.0             1.0
# 1                 0.0             1.0
# 2                 2.0             0.0
# 3                 4.0             3.0
# 4                 2.0             3.0
# ...               ...             ...
# 21537             0.0            10.0
# 21538             0.0             0.0
# 21539             4.0            18.0
# 21540             2.0             4.0
# 21541             2.0             3.0
#
# [21542 rows x 16 columns]

# %%
# dfHealth=dfInspections[['HealthFacilityIDNumber','BusinessName']].groupby(['HealthFacilityIDNumber','BusinessName']).count().reset_index()
dfHealth=dfInspections[['health_license_id','business_name']].groupby(['health_license_id','business_name']).count().reset_index()

# %%
dfHealth.health_license_id.nunique()
# Out:
# 5012

# %% [markdown]
# Each health facilty id number is assigned to a single business, even if two businesses are at the same location

# %%
dfHealth
# Out:
#      health_license_id                   business_name
# 0            LIC107101                  SOTAROL UPTOWN
# 1            LIC107124   HASKELL'S WINE AND CHEESE BAR
# 2            LIC107327                   CRISP & GREEN
# 3            LIC107536  TIM HORTONS CAFE AND BAKE SHOP
# 4            LIC107553      YOGA CENTER OF MINNEAPOLIS
# ...                ...                             ...
# 5007          LIC53824               WHOLE SUM KITCHEN
# 5008          LIC53841          WIILO FOOD DISTRIBUTOR
# 5009          LIC53856                WILDE ROAST CAFE
# 5010          LIC53860                WILDE ROAST CAFE
# 5011          LIC53863                WILDE ROAST CAFE
#
# [5012 rows x 2 columns]

# %%
# df.groupby(['InspectionIDNumber','ViolationPriority']).aggregate({'ViolationIDNumber':'count'})

# %% [markdown]
# ## Create feature for time since last inspection

# %%
# insTimes=df.loc[:,['HealthFacilityIDNumber','DateOfInspection','InspectionIDNumber']]
# insTimes.DateOfInspection=pd.to_datetime(insTimes.DateOfInspection)
# insTimes=insTimes.groupby(['HealthFacilityIDNumber','DateOfInspection','InspectionIDNumber']).count()
# insTimes=insTimes.reset_index()

insTimes=df.loc[:,['health_license_id','date_of_inspection','inspection_id_number']]
insTimes.date_of_inspection=pd.to_datetime(insTimes.date_of_inspection)
insTimes=insTimes.groupby(['health_license_id','date_of_inspection','inspection_id_number']).count()
insTimes=insTimes.reset_index()

# %%
insTimes['years_since_last_inspect']=insTimes.sort_values(['health_license_id','date_of_inspection']).groupby('health_license_id')['date_of_inspection'].diff()
insTimes['years_since_last_inspect']=insTimes['years_since_last_inspect'].dt.days/365

# %%
insTimes[insTimes['years_since_last_inspect']>2].count()
# Out:
# health_license_id           401
# date_of_inspection          401
# inspection_id_number        401
# years_since_last_inspect    401
# dtype: int64

# %%
insTimes['first_inspection_ind']=insTimes.years_since_last_inspect.isna()

# %%
#Set missing time differences (first inspection) to 2 years
insTimes.loc[pd.isnull(insTimes.years_since_last_inspect),'years_since_last_inspect']=2
#Set time differences greater than 2 years to 2 years
insTimes.loc[insTimes['years_since_last_inspect']>2,'years_since_last_inspect']=2

# %%
insTimes.groupby('first_inspection_ind').aggregate({'years_since_last_inspect':'describe'})
# Out:
#                      years_since_last_inspect                          \
#                                         count      mean      std  min
# first_inspection_ind
# False                                 16781.0  1.131913  0.38572  0.0
# True                                   5099.0  2.000000  0.00000  2.0
#
#
#                            25%      50%       75%  max
# first_inspection_ind
# False                 0.956164  0.99726  1.358904  2.0
# True                  2.000000  2.00000  2.000000  2.0

# %%
insTimes=insTimes[['inspection_id_number','years_since_last_inspect','first_inspection_ind']]

# %%
dfInspections=dfInspections.merge(insTimes)

# %%
dfInspections
# Out:
#                         business_name      date_of_inspection  \
# 0      1010 WASHINGTON WINE & SPIRITS 2015-02-27 10:10:00.000
# 1      1010 WASHINGTON WINE & SPIRITS 2017-01-27 12:19:59.999
# 2      1010 WASHINGTON WINE & SPIRITS 2019-02-06 13:20:00.000
# 3                          112 EATERY 2008-09-09 14:09:59.999
# 4                          112 EATERY 2009-11-07 15:45:00.000
# ...                               ...                     ...
# 21537                     ZUMBRO CAFE 2016-11-03 11:29:59.999
# 21538                     ZUMBRO CAFE 2016-11-03 11:29:59.999
# 21539                     ZUMBRO CAFE 2017-10-25 11:40:00.000
# 21540                     ZUMBRO CAFE 2018-12-07 12:19:59.999
# 21541                     ZUMBRO CAFE 2020-01-07 12:00:00.000
#
#       health_license_id  inspection_id_number  inspection_score  \
# 0              LIC42954                 44311                96
# 1              LIC42954                 44314                96
# 2              LIC42954                189485                96
# 3              LIC42959                 44316                82
# 4              LIC42959                 44315                92
# ...                 ...                   ...               ...
# 21537          LIC30942                 24280                92
# 21538          LIC30944                 24301               100
# 21539          LIC30942                 24300                80
# 21540          LIC30942                236468                96
# 21541          LIC30942                281116                96
#
#       inspection_type  latitude  longitude   neighborhood    inspector_name  \
# 0             Routine  44.97659  -93.25502  Downtown East     Jim S Donovan
# 1             Routine  44.97659  -93.25502  Downtown East   Alexander S Kim
# 2             Routine  44.97659  -93.25502  Downtown East      Bob V Becker
# 3             Routine  44.98266  -93.27156  Downtown West        Ellen Hoyt
# 4             Routine  44.98266  -93.27156  Downtown West     Mohamed Yusuf
# ...               ...       ...        ...            ...               ...
# 21537         Routine  44.92447  -93.31501   Linden Hills     Graham Miller
# 21538         Routine  44.92447  -93.31501   Linden Hills     Graham Miller
# 21539         Routine  44.92447  -93.31501   Linden Hills  Eduardo Mardones
# 21540         Routine  44.92447  -93.31501   Linden Hills        SEID SHEKA
# 21541         Routine  44.92447  -93.31501   Linden Hills    Kristine Molde
#
#       facility_category risk_lvl  year_of_inspection  priority_1_ind  \
# 0               GROCERY        3                2015             1.0
# 1               GROCERY        3                2017             1.0
# 2               GROCERY        3                2019             0.0
# 3            RESTAURANT        1                2008             3.0
# 4            RESTAURANT        1                2009             1.0
# ...                 ...      ...                 ...             ...
# 21537        RESTAURANT        1                2016             2.0
# 21538        RESTAURANT        1                2016             0.0
# 21539        RESTAURANT        1                2017             3.0
# 21540        RESTAURANT        1                2018             0.0
# 21541        RESTAURANT        1                2020             1.0
#
#        priority_2_ind  priority_3_ind  years_since_last_inspect  \
# 0                 0.0             1.0                  2.000000
# 1                 0.0             1.0                  1.917808
# 2                 2.0             0.0                  2.000000
# 3                 4.0             3.0                  2.000000
# 4                 2.0             3.0                  1.161644
# ...               ...             ...                       ...
# 21537             0.0            10.0                  0.980822
# 21538             0.0             0.0                  0.980822
# 21539             4.0            18.0                  0.975342
# 21540             2.0             4.0                  1.117808
# 21541             2.0             3.0                  1.082192
#
#        first_inspection_ind
# 0                      True
# 1                     False
# 2                     False
# 3                      True
# 4                     False
# ...                     ...
# 21537                 False
# 21538                 False
# 21539                 False
# 21540                 False
# 21541                 False
#
# [21542 rows x 18 columns]

# %%
# dfInspections['DateOfInspection']=pd.to_datetime(dfInspections.DateOfInspection)
dfInspections['date_of_inspection']=pd.to_datetime(dfInspections.date_of_inspection)

# %%
dfInspections=dfInspections.sort_values(['date_of_inspection','health_license_id'])

# %%
dfInspections['prior_priority_1'] = dfInspections.groupby(['health_license_id'])['priority_1_ind'].shift()

# %%
dfInspections['prior_priority_2'] = dfInspections.groupby(['health_license_id'])['priority_2_ind'].shift()

# %%
dfInspections['prior_priority_3'] = dfInspections.groupby(['health_license_id'])['priority_3_ind'].shift()

# %%
dfInspections[['prior_priority_1','prior_priority_2','prior_priority_3']]=dfInspections[['prior_priority_1','prior_priority_2','prior_priority_3']].fillna(0)

# %%
dfInspections[dfInspections.health_license_id=='LIC47206']
# Out:
#     business_name      date_of_inspection health_license_id  \
# 410  AGRA CULTURE 2007-12-27 15:30:00.000          LIC47206
# 411  AGRA CULTURE 2008-09-03 10:49:59.999          LIC47206
# 412  AGRA CULTURE 2010-01-12 11:05:00.000          LIC47206
# 413  AGRA CULTURE 2011-02-03 13:30:00.000          LIC47206
# 414  AGRA CULTURE 2012-01-06 13:40:00.000          LIC47206
# 415  AGRA CULTURE 2013-01-02 12:39:59.999          LIC47206
# 416  AGRA CULTURE 2014-03-13 12:30:00.000          LIC47206
# 419  AGRA CULTURE 2015-02-06 14:00:00.000          LIC47206
# 425  AGRA CULTURE 2016-01-21 14:50:00.000          LIC47206
# 428  AGRA CULTURE 2017-01-19 15:00:00.000          LIC47206
# 431  AGRA CULTURE 2018-01-09 12:10:00.000          LIC47206
# 435  AGRA CULTURE 2019-01-15 10:35:00.000          LIC47206
# 438  AGRA CULTURE 2020-01-15 11:25:00.000          LIC47206
#
#      inspection_id_number  inspection_score inspection_type  latitude  \
# 410                 51858                98         Routine  44.95821
# 411                 51857               100         Routine  44.95821
# 412                 51852               100         Routine  44.95821
# 413                 51849                90         Routine  44.95821
# 414                 51847                94         Routine  44.95821
# 415                 51845               100         Routine  44.95821
# 416                 51841                94         Routine  44.95821
# 419                 51839                96         Routine  44.95821
# 425                 51837                92         Routine  44.95821
# 428                 51859                96         Routine  44.95821
# 431                188599                86         Routine  44.95821
# 435                237553                94         Routine  44.95821
# 438                287838                92         Routine  44.95821
#
#      longitude neighborhood       inspector_name  ... risk_lvl  \
# 410  -93.27404     Whittier        Mohamed Yusuf  ...        1
# 411  -93.27404     Whittier         Bob V Becker  ...        1
# 412  -93.27404     Whittier         Bob V Becker  ...        1
# 413  -93.27404     Whittier       Kathy L Louden  ...        1
# 414  -93.27404     Whittier       Kathy L Louden  ...        1
# 415  -93.27404     Whittier       Kathy L Louden  ...        1
# 416  -93.27404     Whittier           Anne Stahn  ...        1
# 419  -93.27404     Whittier           Anne Stahn  ...        1
# 425  -93.27404     Whittier  Kevin A Keopraseuth  ...        1
# 428  -93.27404     Whittier  Kevin A Keopraseuth  ...        1
# 431  -93.27404     Whittier     Kenya Urena-Muro  ...        1
# 435  -93.27404     Whittier     Kenya Urena-Muro  ...        1
# 438  -93.27404     Whittier     Kenya Urena-Muro  ...        1
#
#     year_of_inspection  priority_1_ind  priority_2_ind  priority_3_ind  \
# 410               2007             0.0             1.0             3.0
# 411               2008             0.0             0.0             7.0
# 412               2010             0.0             0.0             3.0
# 413               2011             2.0             1.0             2.0
# 414               2012             2.0             1.0             6.0
# 415               2013             0.0             0.0             2.0
# 416               2014             1.0             2.0             5.0
# 419               2015             4.0             2.0             3.0
# 425               2016             0.0             4.0             4.0
# 428               2017             1.0             0.0             1.0
# 431               2018             2.0             3.0             4.0
# 435               2019             1.0             2.0             2.0
# 438               2020             1.0             2.0             0.0
#
#      years_since_last_inspect  first_inspection_ind  prior_priority_1  \
# 410                  2.000000                  True               0.0
# 411                  0.684932                 False               0.0
# 412                  1.358904                 False               0.0
# 413                  1.060274                 False               0.0
# 414                  0.923288                 False               2.0
# 415                  0.989041                 False               2.0
# 416                  1.189041                 False               0.0
# 419                  0.904110                 False               1.0
# 425                  0.956164                 False               4.0
# 428                  0.997260                 False               0.0
# 431                  0.969863                 False               1.0
# 435                  1.013699                 False               2.0
# 438                  1.000000                 False               1.0
#
#      prior_priority_2  prior_priority_3
# 410               0.0               0.0
# 411               1.0               3.0
# 412               0.0               7.0
# 413               0.0               3.0
# 414               1.0               2.0
# 415               1.0               6.0
# 416               0.0               2.0
# 419               2.0               5.0
# 425               2.0               3.0
# 428               4.0               4.0
# 431               0.0               1.0
# 435               3.0               4.0
# 438               2.0               2.0
#
# [13 rows x 21 columns]

# %%
dfInspections['priority_1_ind']=dfInspections['priority_1_ind']>0
dfInspections['priority_2_ind']=dfInspections['priority_2_ind']>0
dfInspections['priority_3_ind']=dfInspections['priority_3_ind']>0

# %%
dfInspections=gpd.GeoDataFrame(dfInspections, geometry=gpd.points_from_xy(dfInspections.longitude, dfInspections.latitude), crs={'init' :'epsg:4326'})

# %%
earliest_inspection=dfInspections.groupby('health_license_id').aggregate(earliest_inspection=('date_of_inspection','min'))

# %%
dfInspections=dfInspections.join(earliest_inspection,on='health_license_id')

# %%
dfInspections.inspection_id_number.nunique()
# Out:
# 21542

# %%
dfInspections['years_since_first_inspection']=dfInspections['date_of_inspection']- dfInspections['earliest_inspection']

# %%
dfInspections['years_since_first_inspection']=dfInspections['years_since_first_inspection'].dt.days/365

# %%
dfInspections['years_since_first_inspection'].describe()
# Out:
# count    21542.000000
# mean         3.175028
# std          3.044964
# min          0.000000
# 25%          0.691096
# 50%          2.317808
# 75%          5.054795
# max         12.093151
# Name: years_since_first_inspection, dtype: float64

# %%
len(dfInspections)
# Out:
# 21542

# %%
dfInspections.nunique()
# Out:
# business_name                3832
# date_of_inspection          18560
# health_license_id            5012
# inspection_id_number        21542
# inspection_score               48
# inspection_type                 1
# latitude                     1348
# longitude                    1344
# neighborhood                   86
# inspector_name                 64
# facility_category               2
# risk_lvl                        4
# year_of_inspection             14
# priority_1_ind                  2
# priority_2_ind                  2
# priority_3_ind                  2
# years_since_last_inspect      711
# first_inspection_ind            2
# prior_priority_1               13
# prior_priority_2               13
# prior_priority_3               31
# geometry                     1628
# dtype: int64

# %%
dfInspections.to_pickle('dfInspections.pickle')
